# %%
import pandas as pd
import numpy as np
import datetime as dt
import warnings
warnings.filterwarnings("ignore")

# Local modules
from src.data_prep import load_online_retail_excel, standardize_year_df, build_transactions, build_rfm_table
from src.segmentation import add_segment_labels, build_segment_summary
from src.clv import add_clv_tenure
from src.clustering import prepare_rfm_for_clustering, find_optimal_k, label_kmeans_clusters
from src.plots import (
    plot_segment_overview,
    plot_rfm_distributions,
    plot_rfm_heatmap,
    plot_scatter_rf,
    plot_elbow_silhouette,
)

# %%
df1, df2 = load_online_retail_excel(
    "online_retail_II.xlsx",
)

# %%
print(df1.shape, df2.shape)
# Out:
# (525461, 8) (541910, 8)

# %%
df1.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
print("---Missing Value in 2009-2010 ---")
print(df1.isnull().sum())

print("---Missing Value in 2010-2011 ---")
print(df2.isnull().sum())
# Out:
# ---Missing Value in 2009-2010 ---
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64
# ---Missing Value in 2010-2011 ---
# Invoice             0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    135080
# Country             0
# dtype: int64

# %%
# Standardize each year DataFrame
before_1, before_2 = df1.shape[0], df2.shape[0]
df1 = standardize_year_df(df1, fill_description=True)
df2 = standardize_year_df(df2, fill_description=True)

print("Rows kept (2009-2010):", df1.shape[0], "/", before_1)
print("Rows kept (2010-2011):", df2.shape[0], "/", before_2)
# Out:
# Rows kept (2009-2010): 417534 / 525461
# Rows kept (2010-2011): 406830 / 541910

# %%
# Build cleaned transactions table

df = build_transactions(df1, df2)

# Duplicate counts (after standardization / merge)
dup_all = df.duplicated().sum()
dup_key = df.duplicated(subset=["Invoice", "StockCode", "Quantity", "InvoiceDate", "CustomerID"]).sum()
print("Duplicate rows (all cols):", dup_all)
print("Duplicate rows (key cols):", dup_key)

print("After cleaning shape:", df.shape)
print("InvoiceDate range:", df["InvoiceDate"].min(), "->", df["InvoiceDate"].max())

df.head()
# Out:
# Duplicate rows (all cols): 26479
# Duplicate rows (key cols): 26562
# After cleaning shape: (805549, 9)
# InvoiceDate range: 2009-12-01 07:45:00 -> 2011-12-09 12:50:00
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  CustomerID         Country  TotalPrice
# 0 2009-12-01 07:45:00   6.95     13085.0  United Kingdom        83.4
# 1 2009-12-01 07:45:00   6.75     13085.0  United Kingdom        81.0
# 2 2009-12-01 07:45:00   6.75     13085.0  United Kingdom        81.0
# 3 2009-12-01 07:45:00   2.10     13085.0  United Kingdom       100.8
# 4 2009-12-01 07:45:00   1.25     13085.0  United Kingdom        30.0

# %%
# RFM metrics
rfm, reference_date = build_rfm_table(df)
print(reference_date)

rfm.describe().T
# Out:
# 2011-12-10 12:50:00
#              count          mean           std       min         25%  \
# CustomerID  5878.0  15315.313542   1715.572666  12346.00  13833.2500
# recency     5878.0    201.331916    209.338707      1.00     26.0000
# frequency   5878.0      6.289384     13.009406      1.00      1.0000
# monetary    5878.0   3018.616737  14737.731040      2.95    348.7625
#
#                   50%       75%        max
# CustomerID  15314.500  16797.75   18287.00
# recency        96.000    380.00     739.00
# frequency       3.000      7.00     398.00
# monetary      898.915   2307.09  608821.65

# %%
rfm.head()
# Out:
#    CustomerID  recency  frequency  monetary
# 0     12346.0      326         12  77556.46
# 1     12347.0        2          8   5633.32
# 2     12348.0       75          5   2019.40
# 3     12349.0       19          4   4428.69
# 4     12350.0      310          1    334.40

# %%
# Scoring (5-quantile)

rfm["R_score"] = pd.qcut(rfm["recency"], 5, labels=[5, 4, 3, 2, 1]).astype(int)
rfm["F_score"] = pd.qcut(rfm["frequency"].rank(method="first"), 5, labels=[1, 2, 3, 4, 5]).astype(int)
rfm["M_score"] = pd.qcut(rfm["monetary"], 5, labels=[1, 2, 3, 4, 5]).astype(int)

rfm["RFM_Segment"] = rfm["R_score"].astype(str) + rfm["F_score"].astype(str) + rfm["M_score"].astype(str)
rfm["RFM_Score"] = rfm["R_score"] + rfm["F_score"] + rfm["M_score"]
rfm.head()
# Out:
#    CustomerID  recency  frequency  monetary  R_score  F_score  M_score  \
# 0     12346.0      326         12  77556.46        2        5        5
# 1     12347.0        2          8   5633.32        5        4        5
# 2     12348.0       75          5   2019.40        3        4        4
# 3     12349.0       19          4   4428.69        5        3        5
# 4     12350.0      310          1    334.40        2        1        2
#
#   RFM_Segment  RFM_Score
# 0         255         12
# 1         545         14
# 2         344         11
# 3         535         13
# 4         212          5

# %%
# Segment labels (rule-based) + summary
rfm = add_segment_labels(rfm)
segment_summary = build_segment_summary(rfm)
segment_summary
# Out:
#                Segment  customers       revenue
# 2            Champions       1300  1.212812e+07
# 7  Potential loyalists       1221  2.548938e+06
# 1     Cannot lose them        227  1.018867e+06
# 3          Hibernating       1523  6.671219e+05
# 0              At risk        597  6.151088e+05
# 6        New customers        443  3.946386e+05
# 5       Need attention        385  2.056168e+05
# 4      Loyal customers        182  1.650231e+05

# %% [markdown]
# ## Imports & Setup

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.stats import zscore

plt.rcParams.update({
    "figure.dpi": 130,
    "axes.spines.top": False,
    "axes.spines.right": False,
    "font.family": "DejaVu Sans",
})

PALETTE = ["#4C72B0","#DD8452","#55A868","#C44E52",
           "#8172B3","#937860","#DA8BC3","#8C8C8C"]

# %% [markdown]
# ## 2 · Rule-Based Segment Visualisations

# %%
plot_segment_overview(segment_summary, palette=PALETTE)

# %%
plot_rfm_distributions(rfm)

# %%
plot_rfm_heatmap(rfm)

# %%
plot_scatter_rf(rfm, palette=PALETTE)

# %% [markdown]
# ## 3 · Customer Lifetime Value (CLV) Estimation

# %%
# --- Tenure / observation-window based CLV (modular) ---
rfm = add_clv_tenure(rfm, df, horizon_months=12, min_obs_days=30)

clv_by_segment = (
    rfm.groupby("Segment")["CLV_12M"]
       .agg(["mean", "median", "sum"])
       .rename(columns={"mean": "Avg CLV", "median": "Median CLV", "sum": "Total CLV"})
       .sort_values("Total CLV", ascending=False)
       .style.format("£{:,.0f}")
)
clv_by_segment
# Out:
# <style type="text/css">
# </style>
# <table id="T_b0373">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0373_level0_col0" class="col_heading level0 col0" >Avg CLV</th>
#       <th id="T_b0373_level0_col1" class="col_heading level0 col1" >Median CLV</th>
#       <th id="T_b0373_level0_col2" class="col_heading level0 col2" >Total CLV</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Segment</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0373_level0_row0" class="row_heading level0 row0" >Champions</th>
#       <td id="T_b0373_row0_col0" class="data row0 col0" >£5,917</td>
#       <td id="T_b0373_row0_col1" class="data row0 col1" >£2,746</td>
#       <td id="T_b0373_row0_col2" class="data row0 col2" >£7,692,018</td>
#     </tr>
#     <tr>
#       <th id="T_b0373_level0_row1" class="row_heading level0 row1" >Potential loyalists</th>
#       <td id="T_b0373_row1_col0" class="data row1 col0" >£2,177</td>
#       <td id="T_b0373_row1_col1" class="data row1 col1" >£1,134</td>
#       <td id="T_b0373_row1_col2" class="data row1 col2" >£2,657,758</td>
#     </tr>
#     <tr>
#       <th id="T_b0373_level0_row2" class="row_heading level0 row2" >New customers</th>
#       <td id="T_b0373_row2_col0" class="data row2 col0" >£3,862</td>
#       <td id="T_b0373_row2_col1" class="data row2 col1" >£2,043</td>
#       <td id="T_b0373_row2_col2" class="data row2 col2" >£1,711,072</td>
#     </tr>
#     <tr>
#       <th id="T_b0373_level0_row3" class="row_heading level0 row3" >Need attention</th>
#       <td id="T_b0373_row3_col0" class="data row3 col0" >£1,432</td>
#       <td id="T_b0373_row3_col1" class="data row3 col1" >£903</td>
#       <td id="T_b0373_row3_col2" class="data row3 col2" >£551,478</td>
#     </tr>
#     <tr>
#       <th id="T_b0373_level0_row4" class="row_heading level0 row4" >Cannot lose them</th>
#       <td id="T_b0373_row4_col0" class="data row4 col0" >£2,384</td>
#       <td id="T_b0373_row4_col1" class="data row4 col1" >£1,292</td>
#       <td id="T_b0373_row4_col2" class="data row4 col2" >£541,251</td>
#     </tr>
#     <tr>
#       <th id="T_b0373_level0_row5" class="row_heading level0 row5" >Hibernating</th>
#       <td id="T_b0373_row5_col0" class="data row5 col0" >£352</td>
#       <td id="T_b0373_row5_col1" class="data row5 col1" >£210</td>
#       <td id="T_b0373_row5_col2" class="data row5 col2" >£535,998</td>
#     </tr>
#     <tr>
#       <th id="T_b0373_level0_row6" class="row_heading level0 row6" >At risk</th>
#       <td id="T_b0373_row6_col0" class="data row6 col0" >£683</td>
#       <td id="T_b0373_row6_col1" class="data row6 col1" >£497</td>
#       <td id="T_b0373_row6_col2" class="data row6 col2" >£407,590</td>
#     </tr>
#     <tr>
#       <th id="T_b0373_level0_row7" class="row_heading level0 row7" >Loyal customers</th>
#       <td id="T_b0373_row7_col0" class="data row7 col0" >£1,069</td>
#       <td id="T_b0373_row7_col1" class="data row7 col1" >£666</td>
#       <td id="T_b0373_row7_col2" class="data row7 col2" >£194,615</td>
#     </tr>
#   </tbody>
# </table>

# %%
# CLV bar chart
clv_df = (
    rfm.groupby("Segment")["CLV_12M"]
       .mean()
       .sort_values(ascending=True)
)

fig, ax = plt.subplots(figsize=(9, 5))
bars = ax.barh(clv_df.index, clv_df.values, color=PALETTE[:len(clv_df)])
ax.set_xlabel("Average 12-Month CLV (£)")
ax.set_title("Estimated CLV per Segment", fontsize=13, fontweight="bold")
for bar, val in zip(bars, clv_df.values):
    ax.text(bar.get_width() + 5, bar.get_y() + bar.get_height()/2,
            f"£{val:,.0f}", va="center", fontsize=8)
plt.tight_layout()
plt.savefig("clv_by_segment.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 4 · K-Means Clustering

# %%
X_scaled = prepare_rfm_for_clustering(rfm)
print(f"Feature matrix shape: {X_scaled.shape}")
# Out:
# Feature matrix shape: (5878, 3)

# %%
k_range = range(2, 11)
results = find_optimal_k(X_scaled, k_range)

# Print curves for quick inspection
for k, inertia, sil in zip(results["k_values"], results["inertias"], results["silhouettes"]):
    print(f"  k={k}  inertia={inertia:,.0f}  silhouette={sil:.4f}")
# Out:
#   File "c:\Users\alkan\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\alkan\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\alkan\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\alkan\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   k=2  inertia=8,589  silhouette=0.4391
#   k=3  inertia=6,353  silhouette=0.3504
#   k=4  inertia=4,920  silhouette=0.3668
#   k=5  inertia=4,100  silhouette=0.3404
#   k=6  inertia=3,555  silhouette=0.3359
#   k=7  inertia=3,193  silhouette=0.2973
#   k=8  inertia=2,899  silhouette=0.2967
#   k=9  inertia=2,656  silhouette=0.2950
#   k=10  inertia=2,471  silhouette=0.2819

# %%
plot_elbow_silhouette(results)
# Out:
# Recommended k = 2  (highest silhouette)

# %%
# ── Fit final model with best k ─────────────────────────────────────────────
BEST_K = results["k_values"][np.argmax(results["silhouettes"])]

km_final = KMeans(n_clusters=4, random_state=42, n_init="auto")
rfm["KMeans_Cluster"] = km_final.fit_predict(X_scaled)

# ── Cluster profiles ─────────────────────────────────────────────────────────
cluster_profile = (
    rfm.groupby("KMeans_Cluster")
       .agg(
           n_customers  =("CustomerID",  "count"),
           avg_recency  =("recency",     "mean"),
           avg_frequency=("frequency",   "mean"),
           avg_monetary =("monetary",    "mean"),
           avg_clv      =("CLV_12M",     "mean"),
       )
       .round(1)
       .sort_values("avg_monetary", ascending=False)
)
print(cluster_profile.to_string())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 10
#       5 rfm["KMeans_Cluster"] = km_final.fit_predict(X_scaled)
#       7 # ── Cluster profiles ─────────────────────────────────────────────────────────
#       8 cluster_profile = (
#       9     rfm.groupby("KMeans_Cluster")
# ---> 10        .agg(
#      11            n_customers  =("CustomerID",  "count"),
#      12            avg_recency  =("recency",     "mean"),
#      13            avg_frequency=("frequency",   "mean"),
#      14            avg_monetary =("monetary",    "mean"),
#      15            avg_clv      =("CLV_12M",     "mean"),
#      16        )
#      17        .round(1)
#      18        .sort_values("avg_monetary", ascending=False)
#      19 )
#      20 print(cluster_profile.to_string())
#
# File c:\Users\alkan\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File c:\Users\alkan\anaconda3\Lib\site-packages\pandas\core\apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
#     193     return self.agg_list_like()
#
# File c:\Users\alkan\anaconda3\Lib\site-packages\pandas\core\apply.py:423, in Apply.agg_dict_like(self)
#     415 def agg_dict_like(self) -> DataFrame | Series:
#     416     """
#     417     Compute aggregation in the case of a dict-like argument.
#     418
#    (...)
#     421     Result of aggregation.
#     422     """
# --> 423     return self.agg_or_apply_dict_like(op_name="agg")
#
# File c:\Users\alkan\anaconda3\Lib\site-packages\pandas\core\apply.py:1608, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1603     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1605 with com.temp_setattr(
#    1606     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1607 ):
# -> 1608     result_index, result_data = self.compute_dict_like(
#    1609         op_name, selected_obj, selection, kwargs
#    1610     )
#    1611 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1612 return result
#
# File c:\Users\alkan\anaconda3\Lib\site-packages\pandas\core\apply.py:462, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     460 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     461 func = cast(AggFuncTypeDict, self.func)
# --> 462 func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     464 is_non_unique_col = (
#     465     selected_obj.ndim == 2
#     466     and selected_obj.columns.nunique() < len(selected_obj.columns)
#     467 )
#     469 if selected_obj.ndim == 1:
#     470     # key only used for output
#
# File c:\Users\alkan\anaconda3\Lib\site-packages\pandas\core\apply.py:663, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     661     cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     662     if len(cols) > 0:
# --> 663         raise KeyError(f"Column(s) {list(cols)} do not exist")
#     665 aggregator_types = (list, tuple, dict)
#     667 # if we have a dict of any non-scalars
#     668 # eg. {'A' : ['mean']}, normalize all to
#     669 # be list-likes
#     670 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['CustomerID'] do not exist"

# %%
cluster_labels = label_kmeans_clusters(cluster_profile)
rfm["KMeans_Label"] = rfm["KMeans_Cluster"].map(cluster_labels)

print(rfm["KMeans_Label"].value_counts())
# Out:
# KMeans_Label
# Lapsed Customers      2044
# Mid-Value Regulars    1464
# Low-Value At-Risk     1242
# High-Value Active     1128
# Name: count, dtype: int64

# %% [markdown]
# ## 5 · Actionable Marketing Recommendations

# %%
ACTION_MAP = {
    "Champions": {
        "priority": "⭐ High",
        "action": "Loyalty rewards, early access, referral program",
        "channel": "Email / Push notification",
        "goal": "Retain & amplify word-of-mouth",
    },
    "Loyal customers": {
        "priority": "⭐ High",
        "action": "Upsell premium products, exclusive member offers",
        "channel": "Email / SMS",
        "goal": "Increase basket size",
    },
    "Potential loyalists": {
        "priority": "🔵 Medium",
        "action": "Onboarding series, personalised recommendations",
        "channel": "Email sequence",
        "goal": "Convert to loyal",
    },
    "New customers": {
        "priority": "🔵 Medium",
        "action": "Welcome discount on 2nd purchase",
        "channel": "Email / Retargeting ads",
        "goal": "Drive repeat purchase",
    },
    "Cannot lose them": {
        "priority": "🔴 Critical",
        "action": "Win-back campaign, personal outreach, strong incentive",
        "channel": "Email + Phone",
        "goal": "Reactivate high-value churned customers",
    },
    "At risk": {
        "priority": "🔴 Critical",
        "action": "Re-engagement email with discount",
        "channel": "Email / SMS",
        "goal": "Prevent full churn",
    },
    "Hibernating": {
        "priority": "🟡 Low",
        "action": "Broad win-back campaign or sunset",
        "channel": "Email",
        "goal": "Low-cost reactivation attempt",
    },
    "Need attention": {
        "priority": "🟡 Low",
        "action": "Survey + targeted offer based on past purchases",
        "channel": "Email",
        "goal": "Understand & re-engage",
    },
    "Promising": {
        "priority": "🔵 Medium",
        "action": "Nurture with relevant content & offers",
        "channel": "Email / Social retargeting",
        "goal": "Move toward loyal",
    },
}

action_df = pd.DataFrame(ACTION_MAP).T.reset_index().rename(columns={"index": "Segment"})

# Merge with segment summary for context
action_df = action_df.merge(
    segment_summary[["Segment", "customers", "revenue"]],
    on="Segment", how="left"
)
action_df["revenue"] = action_df["revenue"].apply(
    lambda x: f"£{x/1e6:.2f}M" if pd.notna(x) else "—"
)
action_df.rename(columns={"customers": "# Customers",
                           "revenue":   "Revenue"}).set_index("Segment")
# Out:
#                        priority  \
# Segment
# Champions                ⭐ High
# Loyal customers          ⭐ High
# Potential loyalists    🔵 Medium
# New customers          🔵 Medium
# Cannot lose them     🔴 Critical
# At risk              🔴 Critical
# Hibernating               🟡 Low
# Need attention            🟡 Low
# Promising              🔵 Medium
#
#                                                                 action  \
# Segment
# Champions              Loyalty rewards, early access, referral program
# Loyal customers       Upsell premium products, exclusive member offers
# Potential loyalists    Onboarding series, personalised recommendations
# New customers                         Welcome discount on 2nd purchase
# Cannot lose them     Win-back campaign, personal outreach, strong i...
# At risk                              Re-engagement email with discount
# Hibernating                          Broad win-back campaign or sunset
# Need attention         Survey + targeted offer based on past purchases
# Promising                       Nurture with relevant content & offers
#
#                                         channel  \
# Segment
# Champions             Email / Push notification
# Loyal customers                     Email / SMS
# Potential loyalists              Email sequence
# New customers           Email / Retargeting ads
# Cannot lose them                  Email + Phone
# At risk                             Email / SMS
# Hibernating                               Email
# Need attention                            Email
# Promising            Email / Social retargeting
#
#                                                         goal  # Customers  \
# Segment
# Champions                     Retain & amplify word-of-mouth       1300.0
# Loyal customers                         Increase basket size        182.0
# Potential loyalists                         Convert to loyal       1221.0
# New customers                          Drive repeat purchase        443.0
# Cannot lose them     Reactivate high-value churned customers        227.0
# At risk                                   Prevent full churn        597.0
# Hibernating                    Low-cost reactivation attempt       1523.0
# Need attention                        Understand & re-engage        385.0
# Promising                                  Move toward loyal          NaN
#
#                      Revenue
# Segment
# Champions            £12.13M
# Loyal customers       £0.17M
# Potential loyalists   £2.55M
# New customers         £0.39M
# Cannot lose them      £1.02M
# At risk               £0.62M
# Hibernating           £0.67M
# Need attention        £0.21M
# Promising                  —

# %% [markdown]
# ## 6 · Final Summary

# %%
total_customers = len(rfm)
total_revenue   = rfm["monetary"].sum()
top_segment     = segment_summary.iloc[0]

print("=" * 55)
print("  RFM Analysis — Executive Summary")
print("=" * 55)
print(f"  Total customers analysed : {total_customers:,}")
print(f"  Total revenue (dataset)  : £{total_revenue:,.0f}")
print(f"  Top segment by revenue   : {top_segment['Segment']}")
print(f"    └─ customers  : {top_segment['customers']:,}")
print(f"    └─ revenue    : £{top_segment['revenue']:,.0f}")
print(f"  K-Means clusters         : {4}")
print("=" * 55)
# Out:
# =======================================================
#   RFM Analysis — Executive Summary
# =======================================================
#   Total customers analysed : 5,878
#   Total revenue (dataset)  : £17,743,429
#   Top segment by revenue   : Champions
#     └─ customers  : 1,300
#     └─ revenue    : £12,128,116
#   K-Means clusters         : 4
# =======================================================
